# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import re
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# 1. Initialize model parameters
class Args:
    maxlen = 50           # Maximum length of user history sequence
    hidden_units = 50     # Dimension of hidden layers
    dropout_rate = 0.2    # Dropout rate
    num_blocks = 2        # Number of Transformer blocks
    num_heads = 5         # Number of heads in multi-head attention
    lr = 0.001            # Learning rate

args = Args()

# 2. Load and preprocess data
# Load data
course_info = pd.read_excel("UW_Courses_with_keywords.xlsx")      # Includes 'Course ID', 'Course Name', 'Key Words'
student_info = pd.read_excel("students_interest.xlsx")            # Includes 'StudentID', 'Interest_1', 'Interest_2', 'history Courses'
student_grades = pd.read_excel("students_info.xlsx")              # Includes 'StudentID', 'Grade', 'Major'

# Merge student information
merged_data = pd.merge(student_grades, student_info, on="StudentID")

# Standardize course IDs
def standardize_course_id(cid):
    return cid.strip().upper()

# Create mapping from course IDs to indices
all_course_ids = course_info['Course ID'].astype(str).unique().tolist()
all_course_ids = [standardize_course_id(cid) for cid in all_course_ids]

course_id_to_idx = {course_id: idx+1 for idx, course_id in enumerate(all_course_ids)}  # Reserve 0 for padding
idx_to_course_id = {idx+1: course_id for idx, course_id in enumerate(all_course_ids)}
itemnum = len(course_id_to_idx)  # Update itemnum

# Extract course grade information, assuming course ID format like 'CSE 400', grade is the first digit
def extract_grade(cid):
    parts = cid.split()
    if len(parts) > 1 and parts[1][0].isdigit():
        return int(parts[1][0])  # Use the hundreds place digit as grade
    else:
        return 0  # Set to 0 if grade cannot be extracted

# Create mapping from grades to indices
all_grades = set()
course_grades = {}
for cid in all_course_ids:
    grade = extract_grade(cid)
    all_grades.add(grade)
    course_grades[cid] = grade

grade_to_idx = {grade: idx+1 for idx, grade in enumerate(sorted(all_grades))}
idx_to_grade = {idx+1: grade for idx, grade in enumerate(sorted(all_grades))}
gradenum = len(grade_to_idx) + 2  # +2 to reserve space for unknown grades and padding

# Preprocess course text content (using only keywords)
# Use course keywords as text content
course_info['Text Content'] = course_info['Key Words'].astype(str)

# Text preprocessing
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation and non-letter characters
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Preprocess text content for all courses
course_info['Processed Text'] = course_info['Text Content'].apply(preprocess_text)

# Build vocabulary
all_text = course_info['Processed Text'].tolist()
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_text)
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1  # Vocabulary size (+1 because index starts from 1, 0 is reserved for padding)

# Convert course text to word index sequences
course_sequences = tokenizer.texts_to_sequences(course_info['Processed Text'])

# Set maximum text length (e.g., 95th percentile of course text lengths)
max_text_len = np.percentile([len(seq) for seq in course_sequences], 95)
max_text_len = int(max_text_len)
if max_text_len == 0:
    max_text_len = 1  # Ensure maximum text length is at least 1

# Pad or truncate sequences
course_padded_sequences = pad_sequences(course_sequences, maxlen=max_text_len, padding='post', truncating='post')

# Map course indices to their text index sequences
course_text_indices = {}
for idx, row in course_info.iterrows():
    cid = standardize_course_id(str(row['Course ID']))
    if cid in course_id_to_idx:
        course_idx = course_id_to_idx[cid]
        course_text_indices[course_idx] = course_padded_sequences[idx]
    else:
        print(f"Course ID {cid} not found in course_id_to_idx.")

# Create mapping array from course indices to grade indices
course_idx_to_grade_idx = np.zeros(itemnum + 1, dtype=np.int32)  # Indices from 0 to itemnum

for i in range(1, itemnum + 1):
    course_id = idx_to_course_id.get(i, None)
    if course_id:
        grade = course_grades.get(course_id, 0)
        grade_idx = grade_to_idx.get(grade, 0)
        course_idx_to_grade_idx[i] = grade_idx
    else:
        course_idx_to_grade_idx[i] = 0  # Unknown course index, set grade to 0

# Convert to TensorFlow constant
course_idx_to_grade_idx_tf = tf.constant(course_idx_to_grade_idx, dtype=tf.int32)

# 3. Process course data and student data
# Process course data
course_data = {
    'course_ids': list(course_id_to_idx.values()),  # Use index list
    'keywords': {}
}

# Create keywords dictionary
for _, row in course_info.iterrows():
    cid = standardize_course_id(str(row['Course ID']))
    if cid in course_id_to_idx:
        idx = course_id_to_idx[cid]
        course_data['keywords'][idx] = row['Key Words']
    else:
        print(f"Course ID {cid} not found in course_id_to_idx.")

# Process student data
student_data = []
for _, row in merged_data.iterrows():
    # Standardize course IDs
    history_course_ids = [standardize_course_id(cid) for cid in str(row['Courses']).split(', ')]
    # Try to map course IDs, record if not mapped
    history_courses = []
    for cid in history_course_ids:
        if cid in course_id_to_idx:
            history_courses.append(course_id_to_idx[cid])
        else:
            print(f"Unmapped course ID {cid} for student {row['StudentID']}")
    student_entry = {
        'id': row['StudentID'],
        'history_courses': history_courses,
        'interest_1': row['Interest_1'],
        'interest_2': row['Interest_2'],
        'grade': row['Grade'],
        'major': row['Major']
    }
    student_data.append(student_entry)

# 4. Define SASRec model (include course grade information and content embeddings)
class SASRec(tf.keras.Model):
    def __init__(self, usernum, itemnum, gradenum, vocab_size, args):
        super(SASRec, self).__init__()
        self.args = args
        self.item_emb = tf.keras.layers.Embedding(input_dim=itemnum + 1, output_dim=args.hidden_units, mask_zero=True)
        self.grade_emb = tf.keras.layers.Embedding(input_dim=gradenum, output_dim=args.hidden_units, mask_zero=True)
        self.pos_emb = tf.keras.layers.Embedding(input_dim=args.maxlen, output_dim=args.hidden_units * 3)
        self.dropout = tf.keras.layers.Dropout(args.dropout_rate)
        self.attention_layers = [
            tf.keras.layers.MultiHeadAttention(num_heads=args.num_heads, key_dim=args.hidden_units * 3) for _ in range(args.num_blocks)
        ]
        self.ffn_layers = [
            tf.keras.Sequential([
                tf.keras.layers.Dense(args.hidden_units * 3, activation='relu'),
                tf.keras.layers.Dense(args.hidden_units * 3)
            ]) for _ in range(args.num_blocks)
        ]
        self.layernorms = [tf.keras.layers.LayerNormalization(epsilon=1e-6) for _ in range(2 * args.num_blocks)]
        self.final_layernorm = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        # Add course content embedding layer
        self.content_emb = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=args.hidden_units, mask_zero=True)
    
    def call(self, inputs, training):
        seq = inputs['seq']             # (batch_size, seq_len)
        grades = inputs['grades']       # (batch_size, seq_len)
        contents = inputs['contents']   # (batch_size, seq_len, max_text_len)

        # Build mask for the sequence
        mask = tf.cast(tf.not_equal(seq, 0), tf.float32)[:, :, tf.newaxis]

        # Course ID embeddings and grade embeddings
        seq_emb = self.item_emb(seq)      # (batch_size, seq_len, hidden_units)
        grade_emb = self.grade_emb(grades)  # (batch_size, seq_len, hidden_units)

        # Course content embeddings
        batch_size, seq_len, text_len = contents.shape
        contents_flat = tf.reshape(contents, [batch_size * seq_len, text_len])  # (batch_size * seq_len, max_text_len)
        content_emb_flat = self.content_emb(contents_flat)  # (batch_size * seq_len, max_text_len, hidden_units)
        # Average the text embeddings for each course
        content_emb_flat = tf.reduce_mean(content_emb_flat, axis=1)  # (batch_size * seq_len, hidden_units)
        content_emb = tf.reshape(content_emb_flat, [batch_size, seq_len, self.args.hidden_units])  # (batch_size, seq_len, hidden_units)

        # Concatenate embedding vectors
        seq_emb = tf.concat([seq_emb, grade_emb, content_emb], axis=-1)  # (batch_size, seq_len, hidden_units * 3)

        # Positional encoding
        pos_indices = tf.range(tf.shape(seq)[1])  # (seq_len,)
        pos_emb = self.pos_emb(pos_indices)       # (seq_len, hidden_units * 3)
        seq_emb += pos_emb  # (batch_size, seq_len, hidden_units * 3)

        # Dropout
        seq_emb = self.dropout(seq_emb, training=training)
        seq_emb *= mask  # Apply mask

        # Multi-layer self-attention and feed-forward network
        for i in range(self.args.num_blocks):
            # Multi-head self-attention
            seq_emb_norm = self.layernorms[2 * i](seq_emb)
            attn_output = self.attention_layers[i](seq_emb_norm, seq_emb_norm, attention_mask=None)
            attn_output = self.dropout(attn_output, training=training)
            seq_emb += attn_output
            seq_emb *= mask  # Apply mask

            # Feed-forward network
            seq_emb_norm = self.layernorms[2 * i + 1](seq_emb)
            ffn_output = self.ffn_layers[i](seq_emb_norm)
            ffn_output = self.dropout(ffn_output, training=training)
            seq_emb += ffn_output
            seq_emb *= mask  # Apply mask

        # Final layer normalization
        seq_emb = self.final_layernorm(seq_emb)  # (batch_size, seq_len, hidden_units * 3)

        return seq_emb  # Return sequence representation for prediction

# 5. Build training data (including course grade information and content embeddings)
train_inputs_seq = []
train_inputs_grades = []
train_inputs_contents = []
train_pos = []
train_neg = []

for student in student_data:
    history = student['history_courses']
    if len(history) < 2:
        continue  # Need at least two courses to create a sequence
    for i in range(1, len(history)):
        seq = history[:i]
        pos_item = history[i]
        # Randomly sample a negative item (course not in history)
        neg_item = np.random.choice([cid for cid in course_data['course_ids'] if cid not in history])

        # Get corresponding grades and content indices
        seq_grades = []
        seq_contents = []
        for cid in seq:
            course_id = idx_to_course_id[cid]
            grade = course_grades.get(course_id, 0)
            grade_idx = grade_to_idx.get(grade, 0)
            seq_grades.append(grade_idx)

            # Get course content index sequence
            content_indices = course_text_indices.get(cid, [0] * max_text_len)
            seq_contents.append(content_indices)

        # Pad sequences
        seq = seq[-args.maxlen:]
        seq_padded = [0] * (args.maxlen - len(seq)) + seq
        seq_grades = seq_grades[-args.maxlen:]
        seq_grades_padded = [0] * (args.maxlen - len(seq_grades)) + seq_grades
        seq_contents = seq_contents[-args.maxlen:]
        seq_contents_padded = [[0]*max_text_len] * (args.maxlen - len(seq_contents)) + seq_contents

        train_inputs_seq.append(seq_padded)
        train_inputs_grades.append(seq_grades_padded)
        train_inputs_contents.append(seq_contents_padded)
        train_pos.append(pos_item)
        train_neg.append(neg_item)

# Convert to NumPy arrays
train_inputs_seq = np.array(train_inputs_seq, dtype=np.int32)              # shape: [num_samples, maxlen]
train_inputs_grades = np.array(train_inputs_grades, dtype=np.int32)        # shape: [num_samples, maxlen]
train_inputs_contents = np.array(train_inputs_contents, dtype=np.int32)    # shape: [num_samples, maxlen, max_text_len]
train_pos = np.array(train_pos, dtype=np.int32)                            # shape: [num_samples]
train_neg = np.array(train_neg, dtype=np.int32)                            # shape: [num_samples]

# Check shapes
print(f"train_inputs_seq shape: {train_inputs_seq.shape}")
print(f"train_inputs_grades shape: {train_inputs_grades.shape}")
print(f"train_inputs_contents shape: {train_inputs_contents.shape}")
print(f"train_pos shape: {train_pos.shape}")
print(f"train_neg shape: {train_neg.shape}")

# 6. Define training and recommendation functions
# Helper function: calculate keyword match score
def calculate_keyword_match_score(course_keywords, student_interest):
    course_keywords = str(course_keywords).strip()
    student_interest = str(student_interest).strip()
    if not course_keywords or not student_interest:
        return 0.0  # Return 0 if keywords or interests are empty
    vectorizer = CountVectorizer().fit_transform([course_keywords, student_interest])
    vectors = vectorizer.toarray()
    if vectors.shape[1] == 0:
        return 0.0  # Return 0 if no common keywords
    cosine_sim = cosine_similarity(vectors)
    return cosine_sim[0, 1]

# Training step function (modified to include course content embeddings)
@tf.function
def train_step(model, inputs_seq, inputs_grades, inputs_contents, pos, pos_contents, neg, neg_contents, optimizer, loss_fn):
    with tf.GradientTape() as tape:
        inputs = {'seq': inputs_seq, 'grades': inputs_grades, 'contents': inputs_contents}
        seq_emb = model(inputs, training=True)
        seq_emb_last = seq_emb[:, -1, :]  # (batch_size, hidden_units * 3)

        # Positive sample embeddings
        pos_grade = tf.gather(course_idx_to_grade_idx_tf, pos)
        pos_emb = model.item_emb(pos)
        pos_grade_emb = model.grade_emb(pos_grade)
        pos_content_emb = model.content_emb(pos_contents)
        pos_content_emb = tf.reduce_mean(pos_content_emb, axis=1)
        pos_emb = tf.concat([pos_emb, pos_grade_emb, pos_content_emb], axis=-1)

        # Negative sample embeddings
        neg_grade = tf.gather(course_idx_to_grade_idx_tf, neg)
        neg_emb = model.item_emb(neg)
        neg_grade_emb = model.grade_emb(neg_grade)
        neg_content_emb = model.content_emb(neg_contents)
        neg_content_emb = tf.reduce_mean(neg_content_emb, axis=1)
        neg_emb = tf.concat([neg_emb, neg_grade_emb, neg_content_emb], axis=-1)

        # Compute logits
        pos_logits = tf.reduce_sum(seq_emb_last * pos_emb, axis=-1)
        neg_logits = tf.reduce_sum(seq_emb_last * neg_emb, axis=-1)

        # Compute loss
        istarget = tf.cast(tf.not_equal(pos, 0), tf.float32)
        loss = tf.reduce_sum(
            loss_fn(tf.ones_like(pos_logits), pos_logits) * istarget +
            loss_fn(tf.zeros_like(neg_logits), neg_logits) * istarget
        ) / tf.reduce_sum(istarget)

    # Apply gradients
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss

# Recommendation generation function (modified to include course content embeddings)
def recommend_courses(model, student_data, course_data, num_recommendations=10):
    recommendations = []
    for student in student_data:
        history_courses = student['history_courses']  # Already a list of integer indices
        if not history_courses:
            print(f"Student {student['id']} has no valid history courses.")
            continue  # Skip if no history courses
        interest_keywords = " ".join([str(student['interest_1']), str(student['interest_2'])])

        # Convert history sequence to fixed length (padding or truncating)
        maxlen = model.args.maxlen
        if len(history_courses) >= maxlen:
            history_seq = history_courses[-maxlen:]
        else:
            history_seq = [0] * (maxlen - len(history_courses)) + history_courses

        # Get corresponding grades and content indices
        history_grades = []
        history_contents = []
        for cid in history_seq:
            if cid == 0:
                history_grades.append(0)
                history_contents.append([0] * max_text_len)
            else:
                course_id = idx_to_course_id[cid]
                grade = course_grades.get(course_id, 0)
                grade_idx = grade_to_idx.get(grade, 0)
                history_grades.append(grade_idx)

                content_indices = course_text_indices.get(cid, [0] * max_text_len)
                history_contents.append(content_indices)

        # Convert to NumPy arrays with integer data type
        history_seq = np.array(history_seq, dtype=np.int32).reshape(1, -1)
        history_grades = np.array(history_grades, dtype=np.int32).reshape(1, -1)
        history_contents = np.array(history_contents, dtype=np.int32).reshape(1, maxlen, max_text_len)

        inputs = {'seq': history_seq, 'grades': history_grades, 'contents': history_contents}

        # Use SASRec model to get sequence representation
        seq_emb = model(inputs, training=False)  # (1, seq_len, hidden_units * 3)
        seq_emb = seq_emb[:, -1, :]  # Take output from the last time step (1, hidden_units * 3)

        # Get embeddings for candidate courses
        candidate_course_indices = np.array(course_data['course_ids'], dtype=np.int32)
        candidate_grades = course_idx_to_grade_idx[candidate_course_indices]
        candidate_emb = model.item_emb(candidate_course_indices)  # (num_items, hidden_units)
        candidate_grade_emb = model.grade_emb(candidate_grades)   # (num_items, hidden_units)

        # Get content embeddings for candidate courses
        candidate_contents = []
        for cid in candidate_course_indices:
            content_indices = course_text_indices.get(cid, [0] * max_text_len)
            candidate_contents.append(content_indices)
        candidate_contents = np.array(candidate_contents, dtype=np.int32)  # (num_items, max_text_len)
        candidate_content_emb = model.content_emb(candidate_contents)  # (num_items, max_text_len, hidden_units)
        candidate_content_emb = tf.reduce_mean(candidate_content_emb, axis=1)  # (num_items, hidden_units)

        # Concatenate embedding vectors
        candidate_emb = tf.concat([candidate_emb, candidate_grade_emb, candidate_content_emb], axis=-1)  # (num_items, hidden_units * 3)

        # Compute scores
        scores = tf.matmul(seq_emb, candidate_emb, transpose_b=True).numpy().flatten()  # (num_items,)

        # Compute keyword match score and combine
        final_scores = []
        for i, course_idx in enumerate(candidate_course_indices):
            course_keywords = course_data['keywords'].get(course_idx, '')
            match_score = calculate_keyword_match_score(course_keywords, interest_keywords)
            final_score = 0.7 * scores[i] + 0.3 * match_score  # Weighted sum
            final_scores.append((student['id'], idx_to_course_id[course_idx], final_score))  # Map back to course ID

        # Add to recommendation list
        final_scores.sort(key=lambda x: x[2], reverse=True)
        recommendations.append((student['id'], final_scores[:num_recommendations]))
    
    return recommendations

# 7. Train the model
# Define optimizer and loss function
optimizer = tf.keras.optimizers.Adam(learning_rate=args.lr)
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# Initialize the model
model = SASRec(usernum=200, itemnum=itemnum, gradenum=gradenum, vocab_size=vocab_size, args=args)

epochs = 10  # Adjust the number of training epochs as needed
batch_size = 64  # Adjust the batch size as needed

num_batches = int(len(train_inputs_seq) / batch_size) + 1

for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs}")
    idx_list = np.arange(len(train_inputs_seq))
    np.random.shuffle(idx_list)
    epoch_loss = 0.0

    for batch_idx in range(num_batches):
        batch_indices = idx_list[batch_idx * batch_size : (batch_idx + 1) * batch_size]
        batch_inputs_seq = train_inputs_seq[batch_indices]
        batch_inputs_grades = train_inputs_grades[batch_indices]
        batch_inputs_contents = train_inputs_contents[batch_indices]
        batch_pos = train_pos[batch_indices]
        batch_neg = train_neg[batch_indices]

        # Prepare pos_contents and neg_contents
        batch_pos_contents = []
        for cid in batch_pos:
            content_indices = course_text_indices.get(cid, [0] * max_text_len)
            batch_pos_contents.append(content_indices)
        batch_pos_contents = np.array(batch_pos_contents, dtype=np.int32)

        batch_neg_contents = []
        for cid in batch_neg:
            content_indices = course_text_indices.get(cid, [0] * max_text_len)
            batch_neg_contents.append(content_indices)
        batch_neg_contents = np.array(batch_neg_contents, dtype=np.int32)

        loss = train_step(
            model,
            batch_inputs_seq,
            batch_inputs_grades,
            batch_inputs_contents,
            batch_pos,
            batch_pos_contents,
            batch_neg,
            batch_neg_contents,
            optimizer,
            loss_fn
        )
        epoch_loss += loss.numpy()

    avg_loss = epoch_loss / num_batches
    print(f"Average loss: {avg_loss:.4f}")

# 8. Generate recommendations
recommended_courses = recommend_courses(model, student_data, course_data)
for rec in recommended_courses:
    student_id = rec[0]
    recommendations = rec[1]
    print(f"Recommendations for student {student_id}:")
    for idx, (sid, course_id, score) in enumerate(recommendations):
        print(f"  {idx+1}. Course ID: {course_id}, Score: {score:.4f}")
# Out:
# train_inputs_seq shape: (3742, 50)
# train_inputs_grades shape: (3742, 50)
# train_inputs_contents shape: (3742, 50, 11)
# train_pos shape: (3742,)
# train_neg shape: (3742,)
# Epoch 1/10
# Average loss: 0.6340
# Epoch 2/10
# Average loss: 0.3633
# Epoch 3/10
# Average loss: 0.2866
# Epoch 4/10
# Average loss: 0.2422
# Epoch 5/10
# Average loss: 0.2144
# Epoch 6/10
# Average loss: 0.1912
# Epoch 7/10
# Average loss: 0.1677
# Epoch 8/10
# Average loss: 0.1544
# Epoch 9/10
# Average loss: 0.1396
# Epoch 10/10
# Average loss: 0.1288
# Recommendations for student S0001:
#   1. Course ID: MATH 506, Score: 4.6603
#   2. Course ID: AMATH 569, Score: 4.6343
#   3. Course ID: MATH 505, Score: 4.5848
#   4. Course ID: AMATH 561, Score: 4.5221
#   5. Course ID: MATH 564, Score: 4.5117
#   6. Course ID: AMATH 573, Score: 4.5112
#   7. Course ID: MATH 545, Score: 4.3564
#   8. Course ID: MATH 544, Score: 4.3361
#   9. Course ID: AMATH 581, Score: 4.3062
#   10. Course ID: AMATH 501, Score: 4.1689
# Recommendations for student S0002:
#   1. Course ID: AMATH 401, Score: 4.9982
#   2. Course ID: MATH 407, Score: 4.8231
#   3. Course ID: MATH 491, Score: 4.7672
#   4. Course ID: AMATH 422, Score: 4.6579
#   5. Course ID: MATH 426, Score: 4.6510
#   10. Course ID: MATH 407, Score: 3.4445
# Recommendations for student S0057:
#   1. Course ID: MATH 394, Score: 4.8946
#   2. Course ID: MATH 334, Score: 4.7454
#   3. Course ID: CSE 311, Score: 4.2409
#   4. Course ID: CSE 312, Score: 4.2366
#   5. Course ID: CSE 332, Score: 4.0482
#   6. Course ID: MATH 300, Score: 3.7359
#   7. Course ID: CSE 351, Score: 3.7151
#   8. Course ID: MATH 318, Score: 3.5746
#   9. Course ID: AMATH 301, Score: 3.4526
#   10. Course ID: AMATH 383, Score: 3.4076
# Recommendations for student S0058:
#   1. Course ID: CSE 311, Score: 4.7853
#   2. Course ID: MATH 394, Score: 4.6507
#   3. Course ID: AMATH 353, Score: 4.3318
#   4. Course ID: CSE 332, Score: 4.1372
#   5. Course ID: CSE 351, Score: 3.9570
#   6. Course ID: CSE 374, Score: 3.7743
#   7. Course ID: E E 351, Score: 3.7238
#   8. Course ID: CSE 312, Score: 3.6649
#   9. Course ID: CSE 352, Score: 3.6071
#   10. Course ID: E E 332, Score: 3.4743
# Recommendations for student S0059:
#   1. Course ID: CSE 311, Score: 5.2234
#   2. Course ID: MATH 394, Score: 5.0863
#   3. Course ID: CSE 332, Score: 4.6435
#   4. Course ID: AMATH 353, Score: 4.6376
#   5. Course ID: CSE 351, Score: 4.3861
#   6. Course ID: CSE 312, Score: 4.2210
#   7. Course ID: CSE 374, Score: 4.1266
#   8. Course ID: CSE 352, Score: 3.9756
#   9. Course ID: CSE 373, Score: 3.7421
#   10. Course ID: AMATH 351, Score: 3.3687
# Recommendations for student S0060:
#   1. Course ID: E E 417, Score: 4.2320
#   2. Course ID: E E 458, Score: 4.1671
#   3. Course ID: MATH 491, Score: 4.1292
#   4. Course ID: E E 416, Score: 4.0299
#   5. Course ID: E E 456, Score: 3.9803
#   6. Course ID: E E 421, Score: 3.9044
#   7. Course ID: E E 452, Score: 3.7598
#   8. Course ID: CSE 446, Score: 3.7389
#   9. Course ID: E E 460, Score: 3.6514
#   10. Course ID: E E 477, Score: 3.6261
# Recommendations for student S0061:
#   1. Course ID: MATH 462, Score: 4.4112
#   2. Course ID: MATH 461, Score: 4.3790
#   3. Course ID: MATH 409, Score: 4.2240
#   4. Course ID: MATH 427, Score: 3.7140
#   5. Course ID: MATH 407, Score: 3.7098
#   6. Course ID: AMATH 401, Score: 3.6404
#   7. Course ID: MATH 444, Score: 3.4144
#   8. Course ID: MATH 464, Score: 3.4068
#   9. Course ID: MATH 420, Score: 3.3996
#   10. Course ID: MATH 426, Score: 3.2947
# Recommendations for student S0062:
#   1. Course ID: CSE 311, Score: 4.8826
#   2. Course ID: MATH 394, Score: 4.6667
#   3. Course ID: AMATH 353, Score: 4.2956
#   4. Course ID: CSE 332, Score: 4.2893
#   5. Course ID: CSE 351, Score: 4.2110
#   6. Course ID: CSE 312, Score: 3.8694
#   7. Course ID: CSE 374, Score: 3.8006
#   8. Course ID: CSE 352, Score: 3.7555
#   9. Course ID: CSE 373, Score: 3.3411
#   2. Course ID: AMATH 561, Score: 4.1435
#   3. Course ID: AMATH 569, Score: 4.0590
#   4. Course ID: MATH 506, Score: 3.6281
#   5. Course ID: MATH 544, Score: 3.5838
#   6. Course ID: MATH 558, Score: 3.5737
#   7. Course ID: MATH 564, Score: 3.5547
#   8. Course ID: AMATH 515, Score: 3.5522
#   9. Course ID: MATH 505, Score: 3.5398
#   10. Course ID: AMATH 518, Score: 3.3686
# Recommendations for student S0082:
#   1. Course ID: MATH 394, Score: 5.0643
#   2. Course ID: CSE 311, Score: 4.9984
#   3. Course ID: CSE 332, Score: 4.4190
#   4. Course ID: CSE 351, Score: 4.3010
#   5. Course ID: CSE 312, Score: 4.1646
#   6. Course ID: AMATH 353, Score: 4.0887
#   7. Course ID: CSE 374, Score: 3.6573
#   8. Course ID: CSE 352, Score: 3.5456
#   9. Course ID: CSE 373, Score: 3.3437
#   10. Course ID: MATH 301, Score: 3.0582
# Recommendations for student S0083:
#   1. Course ID: MATH 208, Score: 4.5376
#   2. Course ID: E E 215, Score: 4.2582
#   3. Course ID: MATH 207, Score: 3.7165
#   4. Course ID: E E 201, Score: 3.6920
#   5. Course ID: E E 271, Score: 3.6156
#   6. Course ID: MATH 224, Score: 3.5097
#   7. Course ID: E E 241, Score: 3.2230
#   8. Course ID: E E 233, Score: 3.1708
#   9. Course ID: E E 242, Score: 3.0876
#   10. Course ID: MATH 209, Score: 2.9395
# Recommendations for student S0084:
#   1. Course ID: CSE 311, Score: 4.7196
#   2. Course ID: MATH 394, Score: 4.4762
#   3. Course ID: AMATH 353, Score: 4.3515
#   4. Course ID: CSE 351, Score: 4.2251
#   5. Course ID: CSE 332, Score: 4.1655
#   6. Course ID: CSE 374, Score: 3.8923
#   7. Course ID: CSE 352, Score: 3.8494
#   8. Course ID: E E 351, Score: 3.6845
#   9. Course ID: CSE 312, Score: 3.6671
#   10. Course ID: E E 332, Score: 3.5633
# Recommendations for student S0085:
#   1. Course ID: E E 417, Score: 4.3277
#   2. Course ID: MATH 491, Score: 4.3120
#   3. Course ID: E E 421, Score: 3.9545
#   4. Course ID: E E 416, Score: 3.8903
#   5. Course ID: E E 456, Score: 3.6565
#   6. Course ID: E E 458, Score: 3.6405
#   7. Course ID: CSE 446, Score: 3.4141
#   8. Course ID: AMATH 401, Score: 3.3815
#   9. Course ID: E E 423, Score: 3.3043
#   10. Course ID: AMATH 422, Score: 3.2159
# Recommendations for student S0086:
#   1. Course ID: E E 215, Score: 4.5252
#   2. Course ID: MATH 208, Score: 3.4122
#   3. Course ID: E E 271, Score: 3.2435
#   4. Course ID: E E 241, Score: 3.1475
#   5. Course ID: E E 201, Score: 3.1373
#   6. Course ID: E E 233, Score: 3.0557
#   7. Course ID: E E 242, Score: 2.9044
#   8. Course ID: MATH 207, Score: 2.6227
#   9. Course ID: MATH 224, Score: 2.2124
#   10. Course ID: MATH 136, Score: 2.0299
# Recommendations for student S0087:
#   1. Course ID: MATH 407, Score: 5.0421
#   2. Course ID: AMATH 401, Score: 4.9588
#   4. Course ID: MATH 506, Score: 4.1730
#   5. Course ID: MATH 505, Score: 4.0804
#   6. Course ID: MATH 564, Score: 4.0081
#   7. Course ID: AMATH 581, Score: 4.0079
#   8. Course ID: MATH 545, Score: 3.9778
#   9. Course ID: MATH 544, Score: 3.9336
#   10. Course ID: AMATH 515, Score: 3.7441
# Recommendations for student S0094:
#   1. Course ID: MATH 409, Score: 4.6682
#   2. Course ID: MATH 407, Score: 4.6232
#   3. Course ID: AMATH 401, Score: 4.5768
#   4. Course ID: MATH 427, Score: 4.2227
#   5. Course ID: MATH 491, Score: 4.2005
#   6. Course ID: MATH 425, Score: 4.1507
#   7. Course ID: MATH 461, Score: 4.1102
#   8. Course ID: MATH 426, Score: 4.0965
#   9. Course ID: MATH 462, Score: 4.0553
#   10. Course ID: MATH 420, Score: 4.0044
# Recommendations for student S0095:
#   1. Course ID: MATH 505, Score: 4.3083
#   2. Course ID: MATH 506, Score: 4.2719
#   3. Course ID: AMATH 561, Score: 4.2533
#   4. Course ID: MATH 545, Score: 4.1718
#   5. Course ID: AMATH 581, Score: 4.1659
#   6. Course ID: AMATH 569, Score: 4.1552
#   7. Course ID: MATH 544, Score: 4.1498
#   8. Course ID: MATH 564, Score: 4.0990
#   9. Course ID: AMATH 573, Score: 4.0673
#   10. Course ID: AMATH 586, Score: 3.7552
# Recommendations for student S0096:
#   1. Course ID: MATH 491, Score: 4.7244
#   2. Course ID: CSE 426, Score: 4.5603
#   3. Course ID: AMATH 482, Score: 4.4409
#   4. Course ID: CSE 446, Score: 4.4086
#   5. Course ID: AMATH 422, Score: 4.3784
#   6. Course ID: CSE 441, Score: 4.3689
#   7. Course ID: AMATH 401, Score: 4.3089
#   8. Course ID: CSE 440, Score: 4.2819
#   9. Course ID: CSE 459, Score: 4.2627
#   10. Course ID: CSE 434, Score: 4.2608
# Recommendations for student S0097:
#   1. Course ID: MATH 461, Score: 3.8854
#   2. Course ID: MATH 462, Score: 3.8464
#   3. Course ID: MATH 409, Score: 3.6335
#   4. Course ID: MATH 402, Score: 3.1437
#   5. Course ID: MATH 444, Score: 2.9542
#   6. Course ID: MATH 427, Score: 2.8975
#   7. Course ID: MATH 407, Score: 2.8781
#   8. Course ID: AMATH 401, Score: 2.7897
#   9. Course ID: MATH 464, Score: 2.7655
#   10. Course ID: MATH 412, Score: 2.6693
# Recommendations for student S0098:
#   1. Course ID: MATH 505, Score: 4.2974
#   2. Course ID: MATH 545, Score: 4.1564
#   3. Course ID: MATH 506, Score: 4.1552
#   4. Course ID: AMATH 561, Score: 4.0876
#   5. Course ID: MATH 564, Score: 4.0555
#   6. Course ID: MATH 544, Score: 4.0293
#   7. Course ID: AMATH 581, Score: 3.9922
#   8. Course ID: AMATH 569, Score: 3.7958
#   9. Course ID: MATH 548, Score: 3.7282
#   10. Course ID: AMATH 501, Score: 3.6615
# Recommendations for student S0099:
#   1. Course ID: MATH 407, Score: 4.9411
#   2. Course ID: MATH 409, Score: 4.8746
#   3. Course ID: AMATH 401, Score: 4.7888
#   4. Course ID: MATH 462, Score: 4.7208
#   5. Course ID: MATH 427, Score: 4.6769
#   6. Course ID: MATH 461, Score: 4.6096
#   7. Course ID: MATH 491, Score: 4.4353
#   8. Course ID: MATH 426, Score: 4.3708
#   9. Course ID: MATH 420, Score: 4.3525
#   10. Course ID: MATH 425, Score: 4.3486
# Recommendations for student S0100:
#   1. Course ID: MATH 461, Score: 4.1749
#   2. Course ID: MATH 462, Score: 4.1259
#   3. Course ID: MATH 409, Score: 3.9934
#   4. Course ID: MATH 407, Score: 3.3444
#   5. Course ID: MATH 402, Score: 3.3031
#   6. Course ID: MATH 427, Score: 3.3026
#   7. Course ID: MATH 444, Score: 3.2724
#   8. Course ID: AMATH 401, Score: 3.2593
#   9. Course ID: MATH 464, Score: 3.1416
#   10. Course ID: MATH 420, Score: 3.1295
# Recommendations for student S0101:
#   1. Course ID: MATH 545, Score: 4.0846
#   2. Course ID: MATH 506, Score: 4.0338
#   3. Course ID: MATH 505, Score: 4.0066
#   4. Course ID: MATH 564, Score: 3.8097
#   5. Course ID: AMATH 561, Score: 3.7978
#   6. Course ID: MATH 544, Score: 3.6786
#   7. Course ID: AMATH 581, Score: 3.5666
#   8. Course ID: AMATH 569, Score: 3.4608
#   9. Course ID: AMATH 573, Score: 3.4201
#   10. Course ID: MATH 565, Score: 3.3583
# Recommendations for student S0102:
#   1. Course ID: MATH 505, Score: 3.9224
#   2. Course ID: MATH 506, Score: 3.8996
#   3. Course ID: MATH 545, Score: 3.8569
#   4. Course ID: AMATH 581, Score: 3.7621
#   5. Course ID: MATH 564, Score: 3.6324
#   6. Course ID: MATH 544, Score: 3.6253
#   7. Course ID: AMATH 561, Score: 3.5125
#   8. Course ID: AMATH 569, Score: 3.4824
#   9. Course ID: MATH 548, Score: 3.4570
#   10. Course ID: AMATH 586, Score: 3.3186
# Recommendations for student S0103:
#   1. Course ID: MATH 208, Score: 3.3645
#   2. Course ID: MATH 224, Score: 2.9924
#   3. Course ID: MATH 207, Score: 2.6748
#   4. Course ID: MATH 209, Score: 2.4915
#   5. Course ID: E E 271, Score: 2.1547
#   6. Course ID: MATH 282, Score: 2.1522
#   7. Course ID: E E 201, Score: 2.0616
#   8. Course ID: E E 241, Score: 1.8696
#   9. Course ID: E E 242, Score: 1.7534
#   10. Course ID: E E 215, Score: 1.7012
# Recommendations for student S0104:
#   1. Course ID: MATH 208, Score: 2.6813
#   2. Course ID: MATH 224, Score: 2.2127
#   3. Course ID: MATH 207, Score: 2.0862
#   4. Course ID: MATH 209, Score: 1.9490
#   5. Course ID: MATH 136, Score: 1.5299
#   6. Course ID: MATH 282, Score: 1.4838
#   7. Course ID: E E 271, Score: 1.3534
#   8. Course ID: CSE 123, Score: 1.2228
#   9. Course ID: E E 242, Score: 1.1458
#   10. Course ID: MATH 135, Score: 1.1364
# Recommendations for student S0105:
#   1. Course ID: E E 215, Score: 4.9975
#   2. Course ID: E E 241, Score: 3.9237
#   3. Course ID: E E 271, Score: 3.8642
#   4. Course ID: E E 242, Score: 3.6098
#   5. Course ID: E E 201, Score: 3.5912
#   6. Course ID: E E 233, Score: 3.5565
#   7. Course ID: MATH 208, Score: 2.9757
#   8. Course ID: E E 299, Score: 2.6741
#   9. Course ID: MATH 207, Score: 2.5013
#   10. Course ID: E E 280, Score: 2.3556
# Recommendations for student S0106:
#   1. Course ID: E E 215, Score: 5.7763
#   2. Course ID: E E 271, Score: 4.6125
#   3. Course ID: E E 201, Score: 4.3600
#   4. Course ID: E E 233, Score: 4.1815
#   5. Course ID: E E 241, Score: 4.1511
#   6. Course ID: E E 242, Score: 3.9946
#   7. Course ID: MATH 208, Score: 3.9086
#   8. Course ID: MATH 207, Score: 3.1067
#   9. Course ID: E E 299, Score: 2.9564
#   10. Course ID: E E 205, Score: 2.6390
# Recommendations for student S0107:
#   1. Course ID: E E 452, Score: 4.2960
#   2. Course ID: E E 436, Score: 4.1145
#   3. Course ID: E E 476, Score: 4.0286
#   4. Course ID: E E 460, Score: 3.9003
#   5. Course ID: E E 351, Score: 3.8917
#   6. Course ID: E E 416, Score: 3.8864
#   7. Course ID: E E 477, Score: 3.8284
#   8. Course ID: E E 438, Score: 3.7946
#   9. Course ID: E E 458, Score: 3.7497
#   10. Course ID: E E 371, Score: 3.7459
# Recommendations for student S0108:
#   1. Course ID: MATH 407, Score: 4.9804
#   2. Course ID: AMATH 401, Score: 4.9570
#   3. Course ID: MATH 409, Score: 4.8252
#   4. Course ID: MATH 427, Score: 4.7463
#   5. Course ID: MATH 462, Score: 4.7403
#   6. Course ID: MATH 426, Score: 4.6840
#   7. Course ID: MATH 491, Score: 4.6492
#   8. Course ID: MATH 425, Score: 4.5859
#   9. Course ID: MATH 492, Score: 4.4908
#   10. Course ID: MATH 461, Score: 4.4637
# Recommendations for student S0109:
#   1. Course ID: AMATH 561, Score: 3.9868
#   2. Course ID: AMATH 569, Score: 3.9741
#   3. Course ID: MATH 506, Score: 3.9227
#   4. Course ID: AMATH 573, Score: 3.9041
#   5. Course ID: AMATH 581, Score: 3.8679
#   6. Course ID: MATH 545, Score: 3.8228
#   7. Course ID: MATH 505, Score: 3.8051
#   8. Course ID: MATH 564, Score: 3.7036
#   9. Course ID: MATH 544, Score: 3.6655
#   10. Course ID: MATH 558, Score: 3.4242
# Recommendations for student S0110:
#   1. Course ID: MATH 491, Score: 4.9273
#   2. Course ID: AMATH 401, Score: 4.7183
#   3. Course ID: MATH 407, Score: 4.5778
#   4. Course ID: AMATH 422, Score: 4.3566
#   5. Course ID: MATH 425, Score: 4.2728
#   6. Course ID: AMATH 482, Score: 4.2563
# ...
#   1. Course ID: MATH 545, Score: 3.7910
#   2. Course ID: MATH 506, Score: 3.7586
#   3. Course ID: MATH 505, Score: 3.6121
#   4. Course ID: MATH 564, Score: 3.4046
#   5. Course ID: MATH 544, Score: 3.2108
#   6. Course ID: AMATH 581, Score: 3.2033
#   7. Course ID: AMATH 561, Score: 3.1059
#   8. Course ID: MATH 565, Score: 3.0838
#   9. Course ID: MATH 548, Score: 3.0513
#   10. Course ID: AMATH 569, Score: 2.8954
# Recommendations for student S0165:
#   1. Course ID: MATH 394, Score: 4.7682
#   2. Course ID: MATH 334, Score: 4.7285
#   3. Course ID: CSE 312, Score: 4.0817
#   4. Course ID: CSE 311, Score: 4.0023
#   5. Course ID: CSE 332, Score: 3.8782
#   6. Course ID: MATH 300, Score: 3.7281
#   7. Course ID: CSE 351, Score: 3.5978
#   8. Course ID: MATH 318, Score: 3.4955
#   9. Course ID: AMATH 301, Score: 3.3927
#   10. Course ID: AMATH 383, Score: 3.3522
# Recommendations for student S0166:
#   1. Course ID: MATH 462, Score: 4.6662
#   2. Course ID: MATH 461, Score: 4.6110
#   3. Course ID: MATH 409, Score: 4.4871
#   4. Course ID: MATH 407, Score: 4.1750
#   5. Course ID: MATH 427, Score: 4.1508
#   6. Course ID: AMATH 401, Score: 4.1115
#   7. Course ID: MATH 420, Score: 3.8119
#   8. Course ID: MATH 464, Score: 3.7332
#   9. Course ID: MATH 425, Score: 3.6584
#   10. Course ID: MATH 426, Score: 3.6450
# Recommendations for student S0167:
#   1. Course ID: CSE 311, Score: 5.0595
#   2. Course ID: MATH 394, Score: 4.7881
#   3. Course ID: AMATH 353, Score: 4.3963
#   4. Course ID: CSE 332, Score: 4.3565
#   5. Course ID: CSE 351, Score: 4.3350
#   6. Course ID: CSE 374, Score: 4.0141
#   7. Course ID: CSE 312, Score: 3.9300
#   8. Course ID: CSE 352, Score: 3.8990
#   9. Course ID: CSE 373, Score: 3.4759
#   10. Course ID: AMATH 351, Score: 3.2599
# Recommendations for student S0168:
#   1. Course ID: MATH 394, Score: 4.8454
#   2. Course ID: CSE 311, Score: 4.4877
#   3. Course ID: CSE 312, Score: 4.0909
#   4. Course ID: CSE 332, Score: 4.0546
#   5. Course ID: MATH 334, Score: 3.9150
#   6. Course ID: CSE 351, Score: 3.7819
#   7. Course ID: MATH 318, Score: 3.3422
#   8. Course ID: AMATH 353, Score: 3.3334
#   9. Course ID: AMATH 301, Score: 3.2145
#   10. Course ID: MATH 301, Score: 3.0876
# Recommendations for student S0169:
#   1. Course ID: MATH 462, Score: 4.2757
#   2. Course ID: MATH 461, Score: 4.2636
#   3. Course ID: MATH 409, Score: 4.0349
#   4. Course ID: MATH 427, Score: 3.4686
#   5. Course ID: MATH 407, Score: 3.4230
#   6. Course ID: AMATH 401, Score: 3.3558
#   7. Course ID: MATH 444, Score: 3.2452
#   8. Course ID: MATH 464, Score: 3.2299
#   9. Course ID: MATH 402, Score: 3.2061
#   10. Course ID: MATH 420, Score: 3.1704
# Recommendations for student S0170:
#   1. Course ID: E E 215, Score: 6.0393
#   2. Course ID: E E 271, Score: 4.5546
#   3. Course ID: E E 201, Score: 4.5420
#   4. Course ID: E E 233, Score: 4.3440
#   5. Course ID: MATH 208, Score: 4.1605
#   6. Course ID: E E 241, Score: 4.0548
#   7. Course ID: E E 242, Score: 3.9922
#   8. Course ID: MATH 207, Score: 3.5070
#   9. Course ID: E E 205, Score: 2.7478
#   10. Course ID: E E 299, Score: 2.7043
# Recommendations for student S0171:
#   1. Course ID: MATH 208, Score: 3.9611
#   2. Course ID: MATH 224, Score: 2.9936
#   3. Course ID: MATH 207, Score: 2.7923
#   4. Course ID: MATH 209, Score: 2.3201
#   5. Course ID: MATH 282, Score: 2.2946
#   6. Course ID: E E 215, Score: 2.2168
#   7. Course ID: E E 201, Score: 2.1405
#   8. Course ID: MATH 135, Score: 1.9018
#   9. Course ID: E E 271, Score: 1.8847
#   10. Course ID: MATH 136, Score: 1.8404
# Recommendations for student S0172:
#   1. Course ID: E E 416, Score: 3.8934
#   2. Course ID: E E 458, Score: 3.8115
#   3. Course ID: E E 460, Score: 3.7468
#   4. Course ID: E E 452, Score: 3.5958
#   5. Course ID: E E 477, Score: 3.5923
#   6. Course ID: E E 476, Score: 3.5856
#   7. Course ID: E E 469, Score: 3.5714
#   8. Course ID: E E 456, Score: 3.5318
#   9. Course ID: E E 417, Score: 3.4401
#   10. Course ID: E E 421, Score: 3.3560
# Recommendations for student S0173:
#   1. Course ID: MATH 208, Score: 2.7607
#   2. Course ID: E E 215, Score: 2.4709
#   3. Course ID: MATH 207, Score: 2.3615
#   4. Course ID: E E 271, Score: 2.2468
#   5. Course ID: E E 201, Score: 2.0333
#   6. Course ID: MATH 224, Score: 2.0155
#   7. Course ID: E E 242, Score: 1.9108
#   8. Course ID: MATH 209, Score: 1.8549
#   9. Course ID: E E 241, Score: 1.8185
#   10. Course ID: E E 233, Score: 1.5218
# Recommendations for student S0174:
#   1. Course ID: E E 215, Score: 5.1048
#   2. Course ID: E E 271, Score: 4.2307
#   3. Course ID: E E 201, Score: 4.1272
#   4. Course ID: MATH 208, Score: 3.9943
#   5. Course ID: E E 241, Score: 3.9217
#   6. Course ID: E E 233, Score: 3.8071
#   7. Course ID: E E 242, Score: 3.6349
#   8. Course ID: MATH 207, Score: 3.5144
#   9. Course ID: MATH 224, Score: 3.0575
#   10. Course ID: E E 299, Score: 2.8959
# Recommendations for student S0175:
#   1. Course ID: MATH 462, Score: 4.9663
#   2. Course ID: MATH 427, Score: 4.7554
#   3. Course ID: MATH 407, Score: 4.6966
#   4. Course ID: MATH 461, Score: 4.6831
#   5. Course ID: AMATH 401, Score: 4.6736
#   6. Course ID: MATH 409, Score: 4.6445
#   7. Course ID: MATH 426, Score: 4.3211
#   8. Course ID: MATH 491, Score: 4.1921
#   9. Course ID: MATH 425, Score: 4.1719
#   10. Course ID: MATH 492, Score: 4.1387
# Recommendations for student S0176:
#   1. Course ID: AMATH 401, Score: 4.9428
#   2. Course ID: MATH 491, Score: 4.8350
#   3. Course ID: MATH 407, Score: 4.6944
#   4. Course ID: AMATH 422, Score: 4.6031
#   5. Course ID: AMATH 482, Score: 4.5742
#   6. Course ID: MATH 427, Score: 4.4066
#   7. Course ID: MATH 426, Score: 4.3421
#   8. Course ID: MATH 425, Score: 4.3018
#   9. Course ID: AMATH 483, Score: 4.2465
#   10. Course ID: MATH 409, Score: 4.2361
# Recommendations for student S0177:
#   1. Course ID: MATH 394, Score: 5.0237
#   2. Course ID: CSE 311, Score: 4.9335
#   3. Course ID: AMATH 353, Score: 4.5484
#   4. Course ID: CSE 332, Score: 4.4369
#   5. Course ID: CSE 351, Score: 4.2047
#   6. Course ID: CSE 312, Score: 4.0401
#   7. Course ID: CSE 374, Score: 3.8604
#   8. Course ID: CSE 352, Score: 3.7543
#   9. Course ID: E E 351, Score: 3.6749
#   10. Course ID: CSE 373, Score: 3.5419
# Recommendations for student S0178:
#   1. Course ID: MATH 491, Score: 4.5750
#   2. Course ID: AMATH 401, Score: 4.0469
#   3. Course ID: CSE 446, Score: 3.7743
#   4. Course ID: AMATH 422, Score: 3.7594
#   5. Course ID: AMATH 482, Score: 3.7308
#   6. Course ID: CSE 426, Score: 3.7016
#   7. Course ID: MATH 407, Score: 3.6378
#   8. Course ID: CSE 459, Score: 3.4340
#   9. Course ID: MATH 425, Score: 3.3976
#   10. Course ID: CSE 434, Score: 3.3774
# Recommendations for student S0179:
#   1. Course ID: AMATH 401, Score: 5.2163
#   2. Course ID: MATH 491, Score: 5.1166
#   3. Course ID: MATH 407, Score: 5.0121
#   4. Course ID: MATH 409, Score: 4.8202
#   5. Course ID: MATH 427, Score: 4.6686
#   6. Course ID: MATH 426, Score: 4.6051
#   7. Course ID: MATH 425, Score: 4.5897
#   8. Course ID: AMATH 422, Score: 4.3994
#   9. Course ID: MATH 492, Score: 4.3917
#   10. Course ID: AMATH 482, Score: 4.3656
# Recommendations for student S0180:
#   1. Course ID: E E 452, Score: 4.0758
#   2. Course ID: E E 436, Score: 4.0304
#   3. Course ID: E E 476, Score: 3.9466
#   4. Course ID: E E 416, Score: 3.8635
#   5. Course ID: E E 460, Score: 3.7919
#   6. Course ID: E E 417, Score: 3.7403
#   7. Course ID: E E 456, Score: 3.7080
#   8. Course ID: E E 458, Score: 3.6976
#   9. Course ID: E E 351, Score: 3.6975
#   10. Course ID: E E 477, Score: 3.5849
# Recommendations for student S0181:
#   1. Course ID: MATH 491, Score: 4.8741
#   2. Course ID: CSE 426, Score: 4.3716
#   3. Course ID: CSE 446, Score: 4.3617
#   4. Course ID: CSE 441, Score: 4.3061
#   5. Course ID: AMATH 482, Score: 4.2541
#   6. Course ID: AMATH 422, Score: 4.1987
#   7. Course ID: AMATH 401, Score: 4.0839
#   8. Course ID: CSE 401, Score: 4.0645
#   9. Course ID: CSE 484, Score: 4.0312
#   10. Course ID: CSE 459, Score: 4.0312
# Recommendations for student S0182:
#   1. Course ID: MATH 427, Score: 4.8354
#   2. Course ID: MATH 407, Score: 4.7952
#   3. Course ID: MATH 462, Score: 4.7158
#   4. Course ID: AMATH 401, Score: 4.6763
#   5. Course ID: MATH 426, Score: 4.5552
#   6. Course ID: MATH 409, Score: 4.4482
#   7. Course ID: MATH 491, Score: 4.4473
#   8. Course ID: AMATH 422, Score: 4.4040
#   9. Course ID: AMATH 482, Score: 4.3790
#   10. Course ID: MATH 492, Score: 4.2981
# Recommendations for student S0183:
#   1. Course ID: E E 510, Score: 4.0141
#   2. Course ID: AMATH 573, Score: 4.0055
#   3. Course ID: E E 532, Score: 3.5887
#   4. Course ID: E E 505, Score: 3.4862
#   5. Course ID: E E 508, Score: 3.4098
#   6. Course ID: CSE 568, Score: 3.3695
#   7. Course ID: AMATH 583, Score: 3.3681
#   8. Course ID: E E 575, Score: 3.3119
#   9. Course ID: E E 535, Score: 3.2228
#   10. Course ID: AMATH 561, Score: 3.1734
# Recommendations for student S0184:
#   1. Course ID: E E 452, Score: 3.9837
#   2. Course ID: E E 476, Score: 3.7441
#   3. Course ID: E E 438, Score: 3.7038
#   4. Course ID: E E 416, Score: 3.6965
#   5. Course ID: E E 351, Score: 3.6216
#   6. Course ID: E E 460, Score: 3.6152
#   7. Course ID: E E 371, Score: 3.5874
#   8. Course ID: E E 418, Score: 3.5770
#   9. Course ID: E E 477, Score: 3.5505
#   10. Course ID: E E 558, Score: 3.4519
# Recommendations for student S0185:
#   1. Course ID: MATH 491, Score: 4.6996
#   2. Course ID: CSE 459, Score: 4.5053
#   3. Course ID: CSE 446, Score: 4.4454
#   4. Course ID: AMATH 482, Score: 4.3768
#   5. Course ID: AMATH 422, Score: 4.3036
#   6. Course ID: CSE 426, Score: 4.2886
#   7. Course ID: CSE 440, Score: 4.1951
#   8. Course ID: AMATH 401, Score: 4.1422
#   9. Course ID: CSE 441, Score: 4.1351
#   10. Course ID: CSE 434, Score: 4.0652
# Recommendations for student S0186:
#   1. Course ID: MATH 461, Score: 3.5509
#   2. Course ID: MATH 462, Score: 3.4744
#   3. Course ID: MATH 409, Score: 3.3550
#   4. Course ID: MATH 402, Score: 3.1196
#   5. Course ID: MATH 444, Score: 2.7351
#   6. Course ID: MATH 407, Score: 2.7051
#   7. Course ID: MATH 464, Score: 2.6241
#   8. Course ID: MATH 427, Score: 2.5787
#   9. Course ID: MATH 412, Score: 2.5546
#   10. Course ID: MATH 208, Score: 2.5494
# Recommendations for student S0187:
#   1. Course ID: MATH 394, Score: 4.7534
#   2. Course ID: CSE 311, Score: 4.2459
#   3. Course ID: MATH 334, Score: 4.1634
#   4. Course ID: CSE 312, Score: 3.9941
#   5. Course ID: CSE 332, Score: 3.9845
#   6. Course ID: CSE 351, Score: 3.7119
#   7. Course ID: MATH 318, Score: 3.2682
#   8. Course ID: AMATH 353, Score: 3.2632
#   9. Course ID: AMATH 301, Score: 3.1715
#   10. Course ID: MATH 300, Score: 3.0257
# Recommendations for student S0188:
#   1. Course ID: E E 215, Score: 3.5711
#   2. Course ID: MATH 208, Score: 3.5296
#   3. Course ID: MATH 136, Score: 2.7663
#   4. Course ID: E E 271, Score: 2.7636
#   5. Course ID: E E 201, Score: 2.6343
#   6. Course ID: MATH 126, Score: 2.5352
#   7. Course ID: MATH 207, Score: 2.4465
#   8. Course ID: MATH 135, Score: 2.3876
#   9. Course ID: E E 241, Score: 2.3509
#   10. Course ID: E E 233, Score: 2.3407
# Recommendations for student S0189:
#   1. Course ID: MATH 505, Score: 4.3868
#   2. Course ID: MATH 506, Score: 4.2772
#   3. Course ID: AMATH 581, Score: 4.2722
#   4. Course ID: MATH 545, Score: 4.2284
#   5. Course ID: MATH 564, Score: 4.1184
#   6. Course ID: MATH 544, Score: 4.0986
#   7. Course ID: AMATH 569, Score: 4.0215
#   8. Course ID: AMATH 561, Score: 4.0095
#   9. Course ID: AMATH 586, Score: 3.8344
#   10. Course ID: MATH 548, Score: 3.7875
# Recommendations for student S0190:
#   1. Course ID: MATH 545, Score: 3.6035
#   2. Course ID: MATH 505, Score: 3.5479
#   3. Course ID: MATH 506, Score: 3.5142
#   4. Course ID: MATH 544, Score: 3.3587
#   5. Course ID: MATH 564, Score: 3.2864
#   6. Course ID: MATH 548, Score: 3.2442
#   7. Course ID: AMATH 561, Score: 3.1683
#   8. Course ID: AMATH 581, Score: 3.1593
#   9. Course ID: MATH 565, Score: 2.9558
#   10. Course ID: AMATH 569, Score: 2.7702
# Recommendations for student S0191:
#   1. Course ID: E E 215, Score: 6.0787
#   2. Course ID: MATH 208, Score: 4.4371
#   3. Course ID: E E 201, Score: 4.3543
#   4. Course ID: E E 271, Score: 4.3152
#   5. Course ID: E E 233, Score: 4.2460
#   6. Course ID: E E 241, Score: 3.8822
#   7. Course ID: E E 242, Score: 3.6144
#   8. Course ID: MATH 207, Score: 3.5839
#   9. Course ID: MATH 224, Score: 2.7713
#   10. Course ID: E E 205, Score: 2.6167
# Recommendations for student S0192:
#   1. Course ID: MATH 394, Score: 4.2579
#   2. Course ID: CSE 311, Score: 4.0359
#   3. Course ID: MATH 334, Score: 3.6234
#   4. Course ID: CSE 332, Score: 3.5637
#   5. Course ID: CSE 312, Score: 3.5298
#   6. Course ID: CSE 351, Score: 3.1815
#   7. Course ID: MATH 318, Score: 2.8485
#   8. Course ID: AMATH 353, Score: 2.7673
#   9. Course ID: AMATH 301, Score: 2.7490
#   10. Course ID: MATH 300, Score: 2.6038
# Recommendations for student S0193:
#   1. Course ID: MATH 334, Score: 4.9902
#   2. Course ID: MATH 394, Score: 4.8769
#   3. Course ID: CSE 312, Score: 4.2405
#   4. Course ID: CSE 311, Score: 4.1858
#   5. Course ID: MATH 300, Score: 4.0121
#   6. Course ID: CSE 332, Score: 3.9929
#   7. Course ID: MATH 318, Score: 3.6730
#   8. Course ID: CSE 351, Score: 3.6397
#   9. Course ID: AMATH 383, Score: 3.5869
#   10. Course ID: AMATH 301, Score: 3.5221
# Recommendations for student S0194:
#   1. Course ID: E E 215, Score: 5.1709
#   2. Course ID: MATH 208, Score: 4.3512
#   3. Course ID: E E 201, Score: 3.6187
#   4. Course ID: E E 233, Score: 3.3922
#   5. Course ID: E E 271, Score: 3.3893
#   6. Course ID: MATH 207, Score: 3.2456
#   7. Course ID: E E 241, Score: 3.0826
#   8. Course ID: E E 242, Score: 2.8239
#   9. Course ID: MATH 224, Score: 2.6701
#   10. Course ID: MATH 209, Score: 2.2273
# Recommendations for student S0195:
#   1. Course ID: E E 452, Score: 4.1150
#   2. Course ID: E E 476, Score: 3.9048
#   3. Course ID: E E 436, Score: 3.7700
#   4. Course ID: E E 438, Score: 3.6867
#   5. Course ID: E E 351, Score: 3.6709
#   6. Course ID: E E 416, Score: 3.6368
#   7. Course ID: E E 460, Score: 3.6055
#   8. Course ID: E E 477, Score: 3.5986
#   9. Course ID: E E 469, Score: 3.5249
#   10. Course ID: E E 371, Score: 3.5047
# Recommendations for student S0196:
#   1. Course ID: MATH 208, Score: 4.5329
#   2. Course ID: MATH 224, Score: 3.3396
#   3. Course ID: MATH 207, Score: 3.3030
#   4. Course ID: E E 215, Score: 3.0189
#   5. Course ID: MATH 209, Score: 2.7687
#   6. Course ID: E E 201, Score: 2.6412
#   7. Course ID: MATH 282, Score: 2.4678
#   8. Course ID: E E 271, Score: 2.3752
#   9. Course ID: E E 233, Score: 2.0346
#   10. Course ID: E E 241, Score: 2.0053
# Recommendations for student S0197:
#   1. Course ID: E E 215, Score: 5.2315
#   2. Course ID: MATH 208, Score: 4.6629
#   3. Course ID: E E 201, Score: 4.1595
#   4. Course ID: E E 271, Score: 4.0309
#   5. Course ID: E E 233, Score: 3.7761
#   6. Course ID: MATH 207, Score: 3.6365
#   7. Course ID: E E 241, Score: 3.5976
#   8. Course ID: E E 242, Score: 3.4536
#   9. Course ID: MATH 224, Score: 3.1390
#   10. Course ID: MATH 209, Score: 2.5066
# Recommendations for student S0198:
#   1. Course ID: MATH 394, Score: 5.5496
#   2. Course ID: CSE 311, Score: 5.5045
#   3. Course ID: CSE 332, Score: 4.9494
#   4. Course ID: CSE 351, Score: 4.8002
#   5. Course ID: AMATH 353, Score: 4.7757
#   6. Course ID: CSE 312, Score: 4.7314
#   7. Course ID: CSE 374, Score: 4.2415
#   8. Course ID: CSE 352, Score: 4.1683
#   9. Course ID: CSE 373, Score: 3.9214
#   10. Course ID: CSE 331, Score: 3.5128
# Recommendations for student S0199:
#   1. Course ID: MATH 491, Score: 4.6883
#   2. Course ID: AMATH 482, Score: 4.1562
#   3. Course ID: AMATH 422, Score: 4.1510
#   4. Course ID: AMATH 401, Score: 3.9685
#   5. Course ID: CSE 446, Score: 3.9552
#   6. Course ID: CSE 426, Score: 3.8252
#   7. Course ID: CSE 441, Score: 3.8214
#   8. Course ID: CSE 434, Score: 3.8073
#   9. Course ID: CSE 401, Score: 3.7718
#   10. Course ID: MATH 407, Score: 3.7066
# Recommendations for student S0200:
#   1. Course ID: MATH 394, Score: 5.0656
#   2. Course ID: CSE 311, Score: 4.9016
#   3. Course ID: CSE 332, Score: 4.3717
#   4. Course ID: CSE 312, Score: 4.2041
#   5. Course ID: CSE 351, Score: 4.1384
#   6. Course ID: AMATH 353, Score: 3.8520
#   7. Course ID: CSE 374, Score: 3.3920
#   8. Course ID: CSE 352, Score: 3.3319
#   9. Course ID: MATH 334, Score: 3.3178
#   10. Course ID: MATH 318, Score: 3.2683
